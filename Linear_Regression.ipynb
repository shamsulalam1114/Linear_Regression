# %% [markdown]
# <a href="https://colab.research.google.com/github/shamsulalam1114/Linear_Regression/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()  # click “Choose Files” and select your CSV
# Out:
#      <input type="file" id="files-c86a1384-72a6-4254-ad14-873b8c11959a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c86a1384-72a6-4254-ad14-873b8c11959a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("nasdaq100.csv", sep=';')

# %%
df.head()
# Out:
#        Date  Starting (USD)  Ending (USD)
# 0  01.01.24           16800         16500
# 1  01.12.23           15900         16100
# 2  01.11.23           15800         15300
# 3  01.10.23           16100         16200
# 4  01.09.23           16300         15700

# %%
df.isnull().sum()
# Out:
# Date              0
# Starting (USD)    0
# Ending (USD)      0
# dtype: int64

# %%
df = df.drop(columns = ['Date'])

# %%
df.head()
# Out:
#    Starting (USD)  Ending (USD)
# 0           16800         16500
# 1           15900         16100
# 2           15800         15300
# 3           16100         16200
# 4           16300         15700

# %%
plt.scatter(df['Starting (USD)'] , df['Ending (USD)'])
plt.xlabel('Starting (USD)')
plt.ylabel('Ending (USD)')
plt.title('NASDAQ100 Stock Prices')
# Out:
# Text(0.5, 1.0, 'NASDAQ100 Stock Prices')

# %%
x = df.drop('Ending (USD)', axis=1)

# %%
x.head()
# Out:
#    Starting (USD)
# 0           16800
# 1           15900
# 2           15800
# 3           16100
# 4           16300

# %%
y = df[['Ending (USD)']]
y.head()
# Out:
#    Ending (USD)
# 0         16500
# 1         16100
# 2         15300
# 3         16200
# 4         15700

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
x.mean()
x.median()
# Out:
# Starting (USD)    16175.0
# dtype: float64

# %%
x.median()
# Out:
# Starting (USD)    16175.0
# dtype: float64

# %%
y.mean()
# Out:
# Ending (USD)    15975.0
# dtype: float64

# %%
plt.scatter(x.mean() , y.mean(), color='red')
plt.scatter(df['Starting (USD)'] , df['Ending (USD)'])
plt.xlabel('Starting (USD)')
plt.ylabel('Ending (USD)')
plt.title('NASDAQ100 Stock Prices')
# Out:
# Text(0.5, 1.0, 'NASDAQ100 Stock Prices')

# %%
reg.fit(x, y)
# Out:
# LinearRegression()

# %%
m = reg.coef_
m
# Out:
# array([[0.65258293]])

# %%
c = reg.intercept_
c
# Out:
# array([5405.87555702])

# %%
m*16700 + c
# Out:
# array([[16304.0105628]])

# %%
df['Predicted_y'] = reg.predict(x)
df.head()
# Out:
#    Starting (USD)  Ending (USD)   Predicted_y
# 0           16800         16500  16369.268856
# 1           15900         16100  15781.944215
# 2           15800         15300  15716.685922
# 3           16100         16200  15912.460802
# 4           16300         15700  16042.977389

# %%
plt.plot(x, reg.predict(x))
plt.scatter(x.mean() , y.mean(), color='red')
plt.scatter(df['Starting (USD)'] , df['Ending (USD)'])
plt.xlabel('Starting (USD)')
plt.ylabel('Ending (USD)')
plt.title('NASDAQ100 Stock Prices')
# Out:
# Text(0.5, 1.0, 'NASDAQ100 Stock Prices')

# %%
reg.predict([[16600]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[16238.75226935]])

# %%
df.head()
# Out:
#    Starting (USD)  Ending (USD)   Predicted_y
# 0           16800         16500  16369.268856
# 1           15900         16100  15781.944215
# 2           15800         15300  15716.685922
# 3           16100         16200  15912.460802
# 4           16300         15700  16042.977389

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
mse = mean_squared_error(df['Ending (USD)'], df['Predicted_y'])
mse
# Out:
# 80411.23397700385

# %%
mae = mean_absolute_error(df['Ending (USD)'], df['Predicted_y'])
mae
# Out:
# 260.3840017604666

# %%
reg.score(x,y)
# Out:
# 0.3577804940272571

# %%
plt.plot(x, reg.predict(x))
plt.scatter(x.mean() , y.mean(), color='red')
plt.scatter(df['Starting (USD)'] , df['Ending (USD)'])
plt.scatter(df['Starting (USD)'] , reg.predict(x))
plt.xlabel('Starting (USD)')
plt.ylabel('Ending (USD)')
plt.title('NASDAQ100 Stock Prices')
# Out:
# Text(0.5, 1.0, 'NASDAQ100 Stock Prices')
