# %% [markdown]
# <a href="https://colab.research.google.com/github/shamsulalam1114/Linear_Regression/blob/main/Car.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
from sklearn import linear_model

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-31e4f45d-2989-4d25-9ea3-808a3ea45775" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-31e4f45d-2989-4d25-9ea3-808a3ea45775">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df= pd.read_csv('car data.csv')

# %%
df
# Out:
#      speed  car_age  experience  risk
# 0      172       22    8.104042    42
# 1       94       17   11.429461    36
# 2      186       20   14.819477    45
# 3      151       10   15.343897    38
# 4      100        6   16.455807    47
# ..     ...      ...         ...   ...
# 275    165       10    8.630563    20
# 276    130       26    6.656316    49
# 277    142       19   14.610983    20
# 278    204        7   13.874352    45
# 279    137        3    3.334615    68
#
# [280 rows x 4 columns]

# %%
df.experience
# Out:
# 0       8.104042
# 1      11.429461
# 2      14.819477
# 3      15.343897
# 4      16.455807
#          ...
# 275     8.630563
# 276     6.656316
# 277    14.610983
# 278    13.874352
# 279     3.334615
# Name: experience, Length: 280, dtype: float64

# %%
exm_fit = df.experience.median()

# %%
exm_fit
# Out:
# 10.582101444783259

# %%
df.experience= df.experience.fillna(exm_fit)

# %%
df.experience
# Out:
# 0      <bound method NDFrame.fillna of 0       8.1040...
# 1      <bound method NDFrame.fillna of 0       8.1040...
# 2      <bound method NDFrame.fillna of 0       8.1040...
# 3      <bound method NDFrame.fillna of 0       8.1040...
# 4      <bound method NDFrame.fillna of 0       8.1040...
#                              ...
# 275    <bound method NDFrame.fillna of 0       8.1040...
# 276    <bound method NDFrame.fillna of 0       8.1040...
# 277    <bound method NDFrame.fillna of 0       8.1040...
# 278    <bound method NDFrame.fillna of 0       8.1040...
# 279    <bound method NDFrame.fillna of 0       8.1040...
# Name: experience, Length: 280, dtype: object

# %%
df
# Out:
#      speed  car_age                                         experience  risk
# 0      172       22  <bound method NDFrame.fillna of 0       8.1040...    42
# 1       94       17  <bound method NDFrame.fillna of 0       8.1040...    36
# 2      186       20  <bound method NDFrame.fillna of 0       8.1040...    45
# 3      151       10  <bound method NDFrame.fillna of 0       8.1040...    38
# 4      100        6  <bound method NDFrame.fillna of 0       8.1040...    47
# ..     ...      ...                                                ...   ...
# 275    165       10  <bound method NDFrame.fillna of 0       8.1040...    20
# 276    130       26  <bound method NDFrame.fillna of 0       8.1040...    49
# 277    142       19  <bound method NDFrame.fillna of 0       8.1040...    20
# 278    204        7  <bound method NDFrame.fillna of 0       8.1040...    45
# 279    137        3  <bound method NDFrame.fillna of 0       8.1040...    68
#
# [280 rows x 4 columns]

# %%
reg= linear_model.LinearRegression()

# %%
print(df[['speed','car_age','experience']].dtypes)
print(df[['speed','car_age','experience']].head())
print(df['risk'].dtype, df['risk'].head())
# Out:
# speed          int64
# car_age        int64
# experience    object
# dtype: object
#    speed  car_age                                         experience
# 0    172       22  <bound method NDFrame.fillna of 0       8.1040...
# 1     94       17  <bound method NDFrame.fillna of 0       8.1040...
# 2    186       20  <bound method NDFrame.fillna of 0       8.1040...
# 3    151       10  <bound method NDFrame.fillna of 0       8.1040...
# 4    100        6  <bound method NDFrame.fillna of 0       8.1040...
# int64 0    42
# 1    36
# 2    45
# 3    38
# 4    47
# Name: risk, dtype: int64

# %%
for col in ['speed','car_age','experience','risk']:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
print(df.isna().sum())
# Out:
# speed           0
# car_age         0
# experience    280
# risk            0
# dtype: int64

# %%
df = df.dropna(subset=['speed','car_age','experience','risk'])

# %%
print(df.isna().sum())
# Out:
# speed         0
# car_age       0
# experience    0
# risk          0
# dtype: int64
